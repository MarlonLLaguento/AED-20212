# %% [markdown]
# # Ejercicios propuestos para examen final

# %% [markdown]
# ##✅ Parte 1- Teoría

# %% [markdown]
# * Ejemplifique un caso donde el ABB(árbol binario de búsqueda) se encuentra en el peor caso posible.
# * Basado en la siguiente lista: D, X, Z, Q, E, T, C, O, P,Y, M, Q.
# > * Simule el ingreso manualmente en un ABB.
# > * Simule el ingreso manualmente en un AVL.
# > * Simule el ingreso en HT (nroBuckets=15)
# > * Realice el paso a paso con el algoritmo de ordenamiento Quicksort, el pivote es al final de la lista.
# > * Realice el paso a paso con el algoritmo de ordenamiento Mergesort.
# > * Realice el paso a paso con el algoritmo de ordenamiento Heapsort.
# > * Después de aplicar cualquier algoritmo de ordenamiento, buscar el elemento  'Y' por el algoritmo "Búsqueda Binaria".

# %% [markdown]
# ##✅ Parte 2- Implementación de métodos

# %% [markdown]
# > Implemente los siguientes métodos para el árbol:
# * Obtenga el menor de los elementos, use puntero a función como parámetro.
# * Mostrar los niveles de un árbol.
# * Muestre la ruta desde la raiz hasta el menor elemento.
# * Inserte los elementos mayores a la izquierda y menores e iguales a la derecha.
# * Actualiza de manera masiva en todos los elementos del árbol.
# * Obtener el puntero del nodo del primer elemento buscado.
# * Mostrar los elementos por niveles.
#
# > Implemente los siguientes métodos para el hashtable:
# * Retorne la cantidad de elementos que sean coincidentes a una condición por parámetro
# * Eliminar un rango de elementos
# * Reemplace un valor del elemento, el parametro de reemplazo como comparación debe ser enviado como función.
# * Devuelva la cantidad de espacios vacios del bucket
# * Devuelva la cantidad de elementos con la condición "esta contenido en"
# * Con uso de bits determinar si un número es par o no.
#
#
# * Realice una depuración paso a paso e indique la función que realiza. implemente 2 casos de prueba (entrada y salida) con catch2
#
# ```
# int funcion(int a, int b) {
#    int x = (a & b) << 1;
#    int y = a^b;
#    if (x == 0)
#       return y;
#    else
#       funcion(x, y);
# }
# ```
#
# ```
# bool funcion(int x)
# {
#     return x && (!(x & (x - 1)));
# }
# ```
#
# ```
# void funcion(int &a, int b)
# {
#     a |= (1 << b);
# }
# ```
#
# ```
# void funcion(int &a, int b)
# {
#
#     a &= (~(1 << b));
# }
# ```
#
# ```
# void funcion(int &a, int b)
# {
#
#     a ^= (1 << b);
# }
# ```

# %% [markdown]
# ##✅ Parte 3- Desarrollo de Caso de Estudio

# %% [markdown]
# ![tabla1.png](data:image/png;base64,...)
#
# •	Implementar una función para indexar filas en arboles desde un archivo, use lambdas:
# > *	Listar alumnos por calificación.
# > *	Contar la cantidad de alumnos entre un rango de calificaciones.
#
# •	Implementar una función para indexar columnas para:
# > *	Obtener la desviación estándar de calificaciones.
# > *	Obtener la mayor calificación.
#
# •	Implementar un HashTable para indexar las filas.
# > *	Realice su función Hash basado en la suma de valores ascci de los apellidos.
# > *	Obtener la moda de las calificaciones.
#
# •	Ordenar los registros por el nombre de manera descendente mediante el algoritmo de mergesort, el criterio de comparación debe ser por un lambda.
#
# •	Realice la comparación de tiempo entre el árbol y el HT.

# %% [markdown]
# ![tabla2.png](data:image/png;base64,...)
